# %%
import pandas as pd
import numpy as np
import re

# %%
# Indicate file path and load it as df 
file_path = 'Resources/scraped_dog_food_20240121.csv'
dog_kibble_df = pd.read_csv(file_path)

dog_kibble_df.head()
# Out:
#                                         Product Name    Price Bag Size  \
# 0  performatrin Ultra Limited Ingredient Kangaroo...  $112.99    24 lb
# 1  performatrin Ultra Wholesome Grains Lamb & Bro...   $86.99    24 lb
# 2  performatrin Prime Chicken & Rice Formula Larg...   $99.99    37 lb
# 3  performatrin Ultra Limited Ingredient Sweet Po...  $115.99    24 lb
# 4            ACANA Classics Red Meat Recipe Dog Food   $98.99  31.9 lb
#
#                                          Description  \
# 0  performatrin Ultra Limited Ingredient Kangaroo...
# 1  performatrin Ultra Wholesome Grains Lamb & Bro...
# 2  performatrin Prime Chicken & Rice Formula Larg...
# 3  performatrin Ultra Limited Ingredient Sweet Po...
# 4  ACANA Classics Red Meat Recipe Dog Food is a m...
#
#                                          Ingredients  \
# 0  Kangaroo, Peas, Chickpeas, Dried Peas, Lentils...
# 1  Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice, Pe...
# 2  Chicken, Chicken Meal (source of Glucosamine a...
# 3  Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4  Raw Beef (16%), Lamb Meal (15%), Pearled Barle...
#
#                                  Guaranteed Analysis Scraping Date  \
# 0  Crude Protein (min.) 24.0% Crude Fat (min.) 14...    2024-01-21
# 1  Crude Protein (min.) 22.0% Crude Fat (min.) 12...    2024-01-21
# 2  Crude Protein (min.) 24.0% Crude Fat (min.) 12...    2024-01-21
# 3  Crude Protein (min.) 21.0% Crude Fat (min.) 11...    2024-01-21
# 4  Crude Protein 27% Fat Content 16% Crude Ash 8%...    2024-01-21
#
#                                         Product Link
# 0  https://www.petvalu.ca/product/performatrin-ul...
# 1  https://www.petvalu.ca/product/performatrin-ul...
# 2  https://www.petvalu.ca/product/performatrin-pr...
# 3  https://www.petvalu.ca/product/performatrin-ul...
# 4  https://www.petvalu.ca/product/acana-classic-r...

# %%
# Get the number of rows & column names
num_rows = dog_kibble_df.shape[0]
column_names = dog_kibble_df.columns.tolist()

print(f"Number of rows: {num_rows}")
print(f"Column names: {column_names}")
# Out:
# Number of rows: 346
# Column names: ['Product Name', 'Price', 'Bag Size', 'Description', 'Ingredients', 'Guaranteed Analysis', 'Scraping Date', 'Product Link']

# %%
# Drop empty rows
dog_kibble_df.dropna(inplace=True)
num_rows_cleaned = dog_kibble_df.shape[0]

print(f"Number of rows after removing empty rows: {num_rows_cleaned}")
# Out:
# Number of rows after removing empty rows: 346

# %%
# Separate the Brand Name from the Kibble Name
brand_names = ["ACANA", "Barker's Complete", "Blue Buffalo", "Diamond Naturals", "Diamond Care", 
               "Gather", "Go! Solutions", "Hill's Science Diet", "Iams", "Lifetime", 
               "Merrick", "Natural Balance", "Now Fresh", "Nutro", "Open Farm", "ORIJEN", 
               "performatrin", "performatrin NATURALS", "performatrin Prime", 
               "performatrin Ultra", "Purina", "Purina Pro Plan", "Royal Canin", "Stella & Chewy's", 
               "Summit", "Taste of the Wild", "Wilder Harrier", "Zignature"]

# Create a pattern to match brand names
brand_pattern = '|'.join(brand_names)

# Extract brand and kibble name using regex
dog_kibble_df[['Brand', 'Kibble Name']] = dog_kibble_df['Product Name'].str.extract(f'({brand_pattern})\s?(.*)', expand=True)

### SEPARATES THE BRANDS EXCEPT FOR WHEN THE BRAND NAME REPEATS LIKE "performatrin", "performatrin NATURALS", "Purina", "Purina Pro Plan"

# %%
# Separate sub brands
sub_brand_names = ["NATURALS", "Prime", "Ultra", "Pro Plan", "Naturals", "Care"]

# Function to check if Kibble Name contains any sub-brand name
def extract_sub_brand(kibble_name):
    return next((sub_brand for sub_brand in sub_brand_names if isinstance(kibble_name, str) and sub_brand in kibble_name), None)

# Create 'Sub Brand' column
dog_kibble_df['Sub Brand'] = dog_kibble_df['Kibble Name'].apply(extract_sub_brand)

# Update 'Brand' column by joining with 'Sub Brand' if applicable
dog_kibble_df['Brand'] = np.where(~dog_kibble_df['Sub Brand'].isna(), dog_kibble_df['Brand'] + ' ' + dog_kibble_df['Sub Brand'], dog_kibble_df['Brand'])

# Remove sub-brand from 'Kibble Name'
def remove_sub_brand(kibble_name, sub_brand):
    if isinstance(kibble_name, str) and isinstance(sub_brand, str):
        return kibble_name.replace(sub_brand, '').strip()
    return kibble_name

dog_kibble_df['Kibble Name'] = dog_kibble_df.apply(lambda row: remove_sub_brand(row['Kibble Name'], row['Sub Brand']), axis=1)

# Drop unnecessary columns
dog_kibble_df.drop(['Product Name', 'Sub Brand'], axis=1, inplace=True)

# %%
# Extract the percentage of Crude Protein
dog_kibble_df['Crude Protein'] = dog_kibble_df['Guaranteed Analysis'].str.extract(r'Crude Protein\s*(.*?)%', expand=False, flags=re.IGNORECASE)

# Fill NaN values with an empty string
dog_kibble_df['Crude Protein'].fillna('', inplace=True)

# Separate Top 5 ingridients 
dog_kibble_df['TOP 5 Ingredients'] = dog_kibble_df['Ingredients'].apply(lambda x: ', '.join(str(x).split(', ')[:5]))

dog_kibble_df.head()
# Out:
#      Price Bag Size                                        Description  \
# 0  $112.99    24 lb  performatrin Ultra Limited Ingredient Kangaroo...
# 1   $86.99    24 lb  performatrin Ultra Wholesome Grains Lamb & Bro...
# 2   $99.99    37 lb  performatrin Prime Chicken & Rice Formula Larg...
# 3  $115.99    24 lb  performatrin Ultra Limited Ingredient Sweet Po...
# 4   $98.99  31.9 lb  ACANA Classics Red Meat Recipe Dog Food is a m...
#
#                                          Ingredients  \
# 0  Kangaroo, Peas, Chickpeas, Dried Peas, Lentils...
# 1  Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice, Pe...
# 2  Chicken, Chicken Meal (source of Glucosamine a...
# 3  Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4  Raw Beef (16%), Lamb Meal (15%), Pearled Barle...
#
#                                  Guaranteed Analysis Scraping Date  \
# 0  Crude Protein (min.) 24.0% Crude Fat (min.) 14...    2024-01-21
# 1  Crude Protein (min.) 22.0% Crude Fat (min.) 12...    2024-01-21
# 2  Crude Protein (min.) 24.0% Crude Fat (min.) 12...    2024-01-21
# 3  Crude Protein (min.) 21.0% Crude Fat (min.) 11...    2024-01-21
# 4  Crude Protein 27% Fat Content 16% Crude Ash 8%...    2024-01-21
#
#                                         Product Link               Brand  \
# 0  https://www.petvalu.ca/product/performatrin-ul...  performatrin Ultra
# 1  https://www.petvalu.ca/product/performatrin-ul...  performatrin Ultra
# 2  https://www.petvalu.ca/product/performatrin-pr...  performatrin Prime
# 3  https://www.petvalu.ca/product/performatrin-ul...  performatrin Ultra
# 4  https://www.petvalu.ca/product/acana-classic-r...               ACANA
#
#                                          Kibble Name Crude Protein  \
# 0  Limited Ingredient Kangaroo Recipe Adult Dog Food   (min.) 24.0
# 1  Wholesome Grains Lamb & Brown Rice Recipe Adul...   (min.) 22.0
# 2  Chicken & Rice Formula Large Breed Adult Dog Food   (min.) 24.0
# 3  Limited Ingredient Sweet Potato & Venison Reci...   (min.) 21.0
# 4                  Classics Red Meat Recipe Dog Food            27
#
#                                    TOP 5 Ingredients
# 0     Kangaroo, Peas, Chickpeas, Dried Peas, Lentils
# 1         Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice
# 2  Chicken, Chicken Meal (source of Glucosamine a...
# 3  Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4  Raw Beef (16%), Lamb Meal (15%), Pearled Barle...

# %%
#Rename and Reorder columns 
dog_kibble_df.rename(columns={'Ingredients': 'Full Ingredient List'}, inplace=True)

new_order = ['Brand', 'Kibble Name', 'Bag Size', 'Price', 'TOP 5 Ingredients', 'Crude Protein', 'Description',
             'Full Ingredient List', 'Guaranteed Analysis', 'Product Link', 'Scraping Date']

dog_kibble_df = dog_kibble_df[new_order]

# %%
dog_kibble_df.head(100)
# Out:
#                  Brand                                        Kibble Name  \
# 0   performatrin Ultra  Limited Ingredient Kangaroo Recipe Adult Dog Food
# 1   performatrin Ultra  Wholesome Grains Lamb & Brown Rice Recipe Adul...
# 2   performatrin Prime  Chicken & Rice Formula Large Breed Adult Dog Food
# 3   performatrin Ultra  Limited Ingredient Sweet Potato & Venison Reci...
# 4                ACANA                  Classics Red Meat Recipe Dog Food
# ..                 ...                                                ...
# 95   Taste of the Wild               High Prairie Canine Formula Dog Food
# 96             Merrick  Real Texas Beef + Sweet Potato Grain-Free Reci...
# 97   Taste of the Wild            Sierra Mountain Canine Formula Dog Food
# 98    Stella & Chewy's                    Raw Coated Beef Recipe Dog Food
# 99               ACANA  Healthy Grains Free-Run Poultry Recipe Adult D...
#
#    Bag Size    Price                                  TOP 5 Ingredients  \
# 0     24 lb  $112.99     Kangaroo, Peas, Chickpeas, Dried Peas, Lentils
# 1     24 lb   $86.99         Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice
# 2     37 lb   $99.99  Chicken, Chicken Meal (source of Glucosamine a...
# 3     24 lb  $115.99  Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4   31.9 lb   $98.99  Raw Beef (16%), Lamb Meal (15%), Pearled Barle...
# ..      ...      ...                                                ...
# 95    28 lb   $97.99  Buffalo, lamb meal, chicken meal, sweet potato...
# 96    22 lb  $128.99  Deboned Beef, Pork Meal, Salmon Meal, Sweet Po...
# 97    28 lb   $97.99    Lamb, lamb meal, sweet potatoes, potatoes, peas
# 98    22 lb   $99.99      Beef, lamb meal, chickpeas, peas, salmon meal
# 99  22.5 lb   $79.99  Fresh chicken (17%), chicken meal (16.5%), oat...
#
#    Crude Protein                                        Description  \
# 0    (min.) 24.0  performatrin Ultra Limited Ingredient Kangaroo...
# 1    (min.) 22.0  performatrin Ultra Wholesome Grains Lamb & Bro...
# 2    (min.) 24.0  performatrin Prime Chicken & Rice Formula Larg...
# 3    (min.) 21.0  performatrin Ultra Limited Ingredient Sweet Po...
# 4             27  ACANA Classics Red Meat Recipe Dog Food is a m...
# ..           ...                                                ...
# 95          32.0  A grain-free formula with sweet potatoes and p...
# 96      (min) 32  Merrick Real Texas Beef + Sweet Potato Grain-F...
# 97          25.0  A lamb protein, grain-free formula for all lif...
# 98    (min) 32.0  Stella & Chewy's Baked Raw Coated Kibble is th...
# 99            29  ACANA Healthy Grains Free-Run Poultry Recipe A...
#
#                                  Full Ingredient List  \
# 0   Kangaroo, Peas, Chickpeas, Dried Peas, Lentils...
# 1   Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice, Pe...
# 2   Chicken, Chicken Meal (source of Glucosamine a...
# 3   Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4   Raw Beef (16%), Lamb Meal (15%), Pearled Barle...
# ..                                                ...
# 95  Buffalo, lamb meal, chicken meal, sweet potato...
# 96  Deboned Beef, Pork Meal, Salmon Meal, Sweet Po...
# 97  Lamb, lamb meal, sweet potatoes, potatoes, pea...
# 98  Beef, lamb meal, chickpeas, peas, salmon meal,...
# 99  Fresh chicken (17%), chicken meal (16.5%), oat...
#
#                                   Guaranteed Analysis  \
# 0   Crude Protein (min.) 24.0% Crude Fat (min.) 14...
# 1   Crude Protein (min.) 22.0% Crude Fat (min.) 12...
# 2   Crude Protein (min.) 24.0% Crude Fat (min.) 12...
# 3   Crude Protein (min.) 21.0% Crude Fat (min.) 11...
# 4   Crude Protein 27% Fat Content 16% Crude Ash 8%...
# ..                                                ...
# 95  Crude Protein 32.0% minimum\nCrude Fat 18.0% m...
# 96  Crude Protein (min) 32% Crude Fat (min) 15% Cr...
# 97  Crude Protein 25.0% minimum\nCrude Fat 15.0% m...
# 98  Crude Protein (min) 32.0%\nCrude Fat (min) 15....
# 99  Crude protein 29% Fat content 17% Crude ash 8%...
#
#                                          Product Link Scraping Date
# 0   https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
# 1   https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
# 2   https://www.petvalu.ca/product/performatrin-pr...    2024-01-21
# 3   https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
# 4   https://www.petvalu.ca/product/acana-classic-r...    2024-01-21
# ..                                                ...           ...
# 95  https://www.petvalu.ca/product/taste-of-the-wi...    2024-01-21
# 96  https://www.petvalu.ca/product/merrick-grain-f...    2024-01-21
# 97  https://www.petvalu.ca/product/taste-of-the-wi...    2024-01-21
# 98  https://www.petvalu.ca/product/stella-chewys-r...    2024-01-21
# 99  https://www.petvalu.ca/product/acana-healthy-g...    2024-01-21
#
# [100 rows x 11 columns]

# %%
# Remove duplicate rows
dog_kibble_df.drop_duplicates(inplace=True)

# Check for missing values in other columns
missing_values = dog_kibble_df.isnull().sum()
missing_values
# Out:
# Brand                   0
# Kibble Name             0
# Bag Size                0
# Price                   0
# TOP 5 Ingredients       0
# Crude Protein           0
# Description             0
# Full Ingredient List    0
# Guaranteed Analysis     0
# Product Link            0
# Scraping Date           0
# dtype: int64

# %%
dog_kibble_df
# Out:
#                   Brand                                        Kibble Name  \
# 0    performatrin Ultra  Limited Ingredient Kangaroo Recipe Adult Dog Food
# 1    performatrin Ultra  Wholesome Grains Lamb & Brown Rice Recipe Adul...
# 2    performatrin Prime  Chicken & Rice Formula Large Breed Adult Dog Food
# 3    performatrin Ultra  Limited Ingredient Sweet Potato & Venison Reci...
# 4                 ACANA                  Classics Red Meat Recipe Dog Food
# ..                  ...                                                ...
# 341        Blue Buffalo  Wilderness Chicken With Grain Small Breed Adul...
# 342           Now Fresh  Grain-Free Turkey, Salmon & Duck Recipe Large ...
# 343         Royal Canin          Breed Health Nutrition Pug Puppy Dog Food
# 344            Lifetime                   Grain-Free Free Run Chicken Meal
# 345  performatrin Ultra         Wholesome Grains Woodlands Recipe Dog Food
#
#     Bag Size    Price                                  TOP 5 Ingredients  \
# 0      24 lb  $112.99     Kangaroo, Peas, Chickpeas, Dried Peas, Lentils
# 1      24 lb   $86.99         Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice
# 2      37 lb   $99.99  Chicken, Chicken Meal (source of Glucosamine a...
# 3      24 lb  $115.99  Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4    31.9 lb   $98.99  Raw Beef (16%), Lamb Meal (15%), Pearled Barle...
# ..       ...      ...                                                ...
# 341   4.5 lb   $33.99  Deboned Chicken, Chicken Meal, Dried Chicken, ...
# 342    25 lb  $125.99  De-boned turkey, potatoes, peas, whole dried e...
# 343   2.5 lb   $36.99  Chicken by-product meal, brewers rice, corn, c...
# 344    25 lb   $63.99  Chicken Meal, Peas, Northern White Beans, Chic...
# 345    12 lb   $54.99  Turkey, Salmon Meal, Oatmeal, Pearled Barley, ...
#
#     Crude Protein                                        Description  \
# 0     (min.) 24.0  performatrin Ultra Limited Ingredient Kangaroo...
# 1     (min.) 22.0  performatrin Ultra Wholesome Grains Lamb & Bro...
# 2     (min.) 24.0  performatrin Prime Chicken & Rice Formula Larg...
# 3     (min.) 21.0  performatrin Ultra Limited Ingredient Sweet Po...
# 4              27  ACANA Classics Red Meat Recipe Dog Food is a m...
# ..            ...                                                ...
# 341          36.0  Blue Buffalo Wilderness Chicken With Grain Sma...
# 342      (min) 25  Now Fresh Grain-Free Turkey, Salmon & Duck Rec...
# 343   (min.) 27.0  Royal Canin Breed Health Nutrition Pug Puppy D...
# 344   (min) 29.0   LIFETIME Grain-Free, Free Run Chicken Recipe A...
# 345   (min.) 28.0  performatrin Ultra Wholesome Grains Woodlands ...
#
#                                   Full Ingredient List  \
# 0    Kangaroo, Peas, Chickpeas, Dried Peas, Lentils...
# 1    Lamb, Lamb Meal, Brown Rice, Oatmeal, Rice, Pe...
# 2    Chicken, Chicken Meal (source of Glucosamine a...
# 3    Sweet Potato, Venison, Peas, Pea Starch, Potat...
# 4    Raw Beef (16%), Lamb Meal (15%), Pearled Barle...
# ..                                                 ...
# 341  Deboned Chicken, Chicken Meal, Dried Chicken, ...
# 342  De-boned turkey, potatoes, peas, whole dried e...
# 343  Chicken by-product meal, brewers rice, corn, c...
# 344  Chicken Meal, Peas, Northern White Beans, Chic...
# 345  Turkey, Salmon Meal, Oatmeal, Pearled Barley, ...
#
#                                    Guaranteed Analysis  \
# 0    Crude Protein (min.) 24.0% Crude Fat (min.) 14...
# 1    Crude Protein (min.) 22.0% Crude Fat (min.) 12...
# 2    Crude Protein (min.) 24.0% Crude Fat (min.) 12...
# 3    Crude Protein (min.) 21.0% Crude Fat (min.) 11...
# 4    Crude Protein 27% Fat Content 16% Crude Ash 8%...
# ..                                                 ...
# 341  Crude Protein 36.0% min Crude Fat 16.0% min Cr...
# 342  Crude Protein (min) 25% Crude Fat (min) 11% Cr...
# 343  Crude Protein (min.) 27.0% Crude Fat (min.) 16...
# 344  Crude Protein(min) 29.0 % Crude Fat (min) 15.0...
# 345  Crude Protein (min.) 28.0% Crude Fat (min.) 14...
#
#                                           Product Link Scraping Date
# 0    https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
# 1    https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
# 2    https://www.petvalu.ca/product/performatrin-pr...    2024-01-21
# 3    https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
# 4    https://www.petvalu.ca/product/acana-classic-r...    2024-01-21
# ..                                                 ...           ...
# 341  https://www.petvalu.ca/product/blue-buffalo-wi...    2024-01-21
# 342  https://www.petvalu.ca/product/now-fresh-grain...    2024-01-21
# 343  https://www.petvalu.ca/product/royal-canin-bre...    2024-01-21
# 344  https://www.petvalu.ca/product/lifetime-grain-...    2024-01-21
# 345  https://www.petvalu.ca/product/performatrin-ul...    2024-01-21
#
# [346 rows x 11 columns]

# %%
# Specify the file path to save the cleaned DataFrame
output_file_path = 'Resources/cleaned_dog_food_data.csv'

dog_kibble_df.to_csv(output_file_path, index=False)

print(f"Data saved to: {output_file_path}")
# Out:
# Data saved to: cleaned_dog_food_data.csv
